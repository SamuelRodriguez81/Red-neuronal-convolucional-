# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelRodriguez81/Red-neuronal-convolucional-/blob/main/A3_Entrenamiento_de_red_neuronal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Samuel Rodriguez Godinez
#Matricula:2082270
#Materia: Inteligencia Artificial y rede neuronales


import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.utils import np_utils
# generador de números aleatorios
seed = 7
numpy.random.seed(seed)
# cargamos los datos
(X_train, y_train), (X_test, y_test) = mnist.load_data()
num_pixels = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], num_pixels).astype('float32')
X_test = X_test.reshape(X_test.shape[0], num_pixels).astype('float32')
# normalizamos las entradas desde 0-255 a 0-1
X_train = X_train / 255
X_test = X_test / 255
# una codificacion en caliente a la salida
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]
# definismos la linea base del modelo
def baseline_model():
  # creamos el modelo
  model = Sequential()
  model.add(Dense(num_pixels, input_dim=num_pixels, kernel_initializer='normal',
     activation='relu'))
  model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))
  # Compilamos el modelo
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model
  # construye el modelo
model = baseline_model()
# ajusta el modelo
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200,
verbose=2)
# Final evaluacion del model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Error de linea base: %.2f%%" % (100-scores[1]*100))
# linea base de MLP para MNIST dataset
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
# semilla de reproducibilidad
seed = 7
numpy.random.seed(seed)
# cargamos los datos
(X_train, y_train), (X_test, y_test) = mnist.load_data()

num_pixels = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], num_pixels).astype('float32')
X_test = X_test.reshape(X_test.shape[0], num_pixels).astype('float32')
# normaliza las entradas de 0-255 a 0-1
X_train = X_train / 255
X_test = X_test / 255
# codificacion en caliente a la salida
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

# define la linea base del modelo
def baseline_model():
  # crea el modelo
  model = Sequential()
  model.add(Dense(num_pixels, input_dim=num_pixels, kernel_initializer='normal',
activation='relu'))
  model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))
  # Compila el modelo
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

# Construir del modelo
model = baseline_model()
# Ajusta el modelo
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200,
verbose=2)
# Final evaluacion del modelo
scores = model.evaluate(X_test, y_test, verbose=0)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 300/300 - 13s - loss: 0.2792 - accuracy: 0.9208 - val_loss: 0.1422 - val_accuracy: 0.9595 - 13s/epoch - 43ms/step
# Epoch 2/10
# 300/300 - 8s - loss: 0.1089 - accuracy: 0.9692 - val_loss: 0.0975 - val_accuracy: 0.9721 - 8s/epoch - 27ms/step
# Epoch 3/10
# 300/300 - 5s - loss: 0.0688 - accuracy: 0.9801 - val_loss: 0.0807 - val_accuracy: 0.9749 - 5s/epoch - 17ms/step
# Epoch 4/10
# 300/300 - 7s - loss: 0.0485 - accuracy: 0.9862 - val_loss: 0.0666 - val_accuracy: 0.9798 - 7s/epoch - 23ms/step
# Epoch 5/10
# 300/300 - 6s - loss: 0.0363 - accuracy: 0.9894 - val_loss: 0.0734 - val_accuracy: 0.9773 - 6s/epoch - 19ms/step
# Epoch 6/10
# 300/300 - 6s - loss: 0.0259 - accuracy: 0.9934 - val_loss: 0.0671 - val_accuracy: 0.9785 - 6s/epoch - 19ms/step
# Epoch 7/10
# 300/300 - 4s - loss: 0.0193 - accuracy: 0.9952 - val_loss: 0.0602 - val_accuracy: 0.9805 - 4s/epoch - 13ms/step
# Epoch 8/10
# 300/300 - 4s - loss: 0.0134 - accuracy: 0.9973 - val_loss: 0.0632 - val_accuracy: 0.9804 - 4s/epoch - 13ms/step
# Epoch 9/10
# 300/300 - 5s - loss: 0.0104 - accuracy: 0.9979 - val_loss: 0.0608 - val_accuracy: 0.9812 - 5s/epoch - 17ms/step
# Epoch 10/10
# 300/300 - 4s - loss: 0.0081 - accuracy: 0.9985 - val_loss: 0.0567 - val_accuracy: 0.9835 - 4s/epoch - 13ms/step
# Error de linea base: 1.65%
# Epoch 1/10
# 300/300 - 6s - loss: 0.2837 - accuracy: 0.9191 - val_loss: 0.1406 - val_accuracy: 0.9605 - 6s/epoch - 19ms/step
# Epoch 2/10
# 300/300 - 4s - loss: 0.1128 - accuracy: 0.9670 - val_loss: 0.0991 - val_accuracy: 0.9701 - 4s/epoch - 13ms/step
# Epoch 3/10
# 300/300 - 4s - loss: 0.0730 - accuracy: 0.9791 - val_loss: 0.0764 - val_accuracy: 0.9752 - 4s/epoch - 13ms/step
# Epoch 4/10
# 300/300 - 5s - loss: 0.0514 - accuracy: 0.9851 - val_loss: 0.0691 - val_accuracy: 0.9774 - 5s/epoch - 18ms/step
# Epoch 5/10
# 300/300 - 4s - loss: 0.0371 - accuracy: 0.9894 - val_loss: 0.0674 - val_accuracy: 0.9793 - 4s/epoch - 13ms/step
# Epoch 6/10
# 300/300 - 4s - loss: 0.0278 - accuracy: 0.9927 - val_loss: 0.0642 - val_accuracy: 0.9797 - 4s/epoch - 13ms/step
# Epoch 7/10
# 300/300 - 5s - loss: 0.0193 - accuracy: 0.9951 - val_loss: 0.0593 - val_accuracy: 0.9824 - 5s/epoch - 17ms/step
# Epoch 8/10
# 300/300 - 4s - loss: 0.0140 - accuracy: 0.9969 - val_loss: 0.0577 - val_accuracy: 0.9814 - 4s/epoch - 13ms/step
# Epoch 9/10
# 300/300 - 4s - loss: 0.0109 - accuracy: 0.9976 - val_loss: 0.0616 - val_accuracy: 0.9814 - 4s/epoch - 13ms/step
# Epoch 10/10
# 300/300 - 5s - loss: 0.0082 - accuracy: 0.9985 - val_loss: 0.0588 - val_accuracy: 0.9831 - 5s/epoch - 17ms/step
# Baseline Error: 1.69%
